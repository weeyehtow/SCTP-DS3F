# %%
import pandas as pd
import numpy as np

print("Pandas version:", pd.__version__)
print("Numpy version:", np.__version__)

import csv
from itertools import islice

with open('/home/user/Downloads/leads_env/SGJobData.csv', newline='') as f:
    csvfile = csv.reader(f)
    for row in islice(csvfile, 5):
        print(row)
# Out:
# Pandas version: 1.5.3
# Numpy version: 1.26.4
# ['categories', 'employmentTypes', 'metadata_expiryDate', 'metadata_isPostedOnBehalf', 'metadata_jobPostId', 'metadata_newPostingDate', 'metadata_originalPostingDate', 'metadata_repostCount', 'metadata_totalNumberJobApplication', 'metadata_totalNumberOfView', 'minimumYearsExperience', 'numberOfVacancies', 'occupationId', 'positionLevels', 'postedCompany_name', 'salary_maximum', 'salary_minimum', 'salary_type', 'status_id', 'status_jobStatus', 'title', 'average_salary']
# ['[{"id":13,"category":"Environment / Health"},{"id":25,"category":"Manufacturing"},{"id":36,"category":"Sciences / Laboratory / R&D"}]', 'Permanent', '2023-05-08', 'False', 'MCF-2023-0252866', '2023-04-08', '2023-03-30', '2', '5', '151', '0', '1', '', 'Executive', 'WORKSTONE PTE. LTD.', '2800', '2000', 'Monthly', '0', 'Closed', 'Food Technologist - Clementi | Entry Level | Up to $2,800', '2400.0']
# ['[{"id":21,"category":"Information Technology"}]', 'Permanent', '2023-05-08', 'False', 'MCF-2023-0273977', '2023-04-08', '2023-04-08', '0', '0', '55', '2', '2', '', 'Executive', 'TRUST RECRUIT PTE. LTD.', '5500', '4000', 'Monthly', '0', 'Closed', 'Software Engineer (Fab Support) (Java, CIM, Up to $ 5.5K) - DS', '4750.0']
# ['[{"id":33,"category":"Repair and Maintenance"}]', 'Full Time', '2023-04-22', 'False', 'MCF-2023-0273994', '2023-04-08', '2023-04-08', '0', '7', '99', '3', '1', '', 'Senior Executive', 'PU TIEN SERVICES PTE. LTD.', '4600', '3800', 'Monthly', '0', 'Closed', 'Senior Technician', '4200.0']
# ['[{"id":21,"category":"Information Technology"}]', 'Permanent', '2023-05-08', 'False', 'MCF-2023-0273991', '2023-04-08', '2023-04-08', '0', '6', '113', '8', '1', '', 'Senior Executive', 'TRUST RECRUIT PTE. LTD.', '10000', '5000', 'Monthly', '0', 'Closed', 'Senior .NET Developer (.NET Core, MVC, MVVC, SharePoint) - DS', '7500.0']
